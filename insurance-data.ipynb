# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('insurance-data.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True )

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
df_1=df.dropna()

# %%
df_1
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.notnull().sum()
# Out:
# age         1337
# sex         1337
# bmi         1337
# children    1337
# smoker      1337
# region      1337
# charges     1337
# dtype: int64

# %%
#  Now what is the max age 
df[df['age']==df['age'].max()]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 62     64    male  24.700         1     no  northwest  30166.61817
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 199    64  female  39.330         0     no  northeast  14901.51670
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 398    64    male  25.600         2     no  southwest  14988.43200
# 402    64  female  32.965         0     no  northwest  14692.66935
# 418    64    male  39.160         1     no  southeast  14418.28040
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 534    64    male  40.480         0     no  southeast  13831.11520
# 603    64  female  39.050         3     no  southeast  16085.12750
# 635    64    male  38.190         0     no  northeast  14410.93210
# ...

# %%
#  what is the max age  ?
df[(df['age']==df['age'].max() )]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 62     64    male  24.700         1     no  northwest  30166.61817
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 199    64  female  39.330         0     no  northeast  14901.51670
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 398    64    male  25.600         2     no  southwest  14988.43200
# 402    64  female  32.965         0     no  northwest  14692.66935
# 418    64    male  39.160         1     no  southeast  14418.28040
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 534    64    male  40.480         0     no  southeast  13831.11520
# 603    64  female  39.050         3     no  southeast  16085.12750
# 635    64    male  38.190         0     no  northeast  14410.93210
# ...

# %%
df[df['children']==df['children'].max()]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 32     19  female  28.600         5     no  southwest   4687.79700
# 71     31    male  28.500         5     no  northeast   6799.45800
# 166    20  female  37.000         5     no  southwest   4830.63000
# 413    25    male  23.900         5     no  southwest   5080.09600
# 425    45    male  24.310         5     no  southeast   9788.86590
# 438    52  female  46.750         5     no  southeast  12592.53450
# 568    49  female  31.900         5     no  southwest  11552.90400
# 640    33    male  42.400         5     no  southwest   6666.24300
# 877    33    male  33.440         5     no  southeast   6653.78860
# 932    46    male  25.800         5     no  southwest  10096.97000
# 937    39  female  24.225         5     no  northwest   8965.79575
# 969    39  female  34.320         5     no  southeast   8596.82780
# 984    20    male  30.115         5     no  northeast   4915.05985
# ...

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.boxplot(x='charges',data=df);

# %%
df=df.query("charges<40000")

# %%
sns.boxplot(x='charges',data=df);

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1258.000000  1258.000000  1258.000000   1258.000000
# mean     38.624006    30.283037     1.082671  11244.344235
# std      14.016389     5.985870     1.209023   9182.733316
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    25.935000     0.000000   4527.756463
# 50%      38.000000    29.925000     1.000000   8749.239125
# 75%      51.000000    34.103750     2.000000  13911.859300
# max      64.000000    53.130000     5.000000  39983.425950

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1258 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1258 non-null   int64
#  1   sex       1258 non-null   object
#  2   bmi       1258 non-null   float64
#  3   children  1258 non-null   int64
#  4   smoker    1258 non-null   object
#  5   region    1258 non-null   object
#  6   charges   1258 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 78.6+ KB

# %%
df.head(100)
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0     19  female  27.900         0    yes  southwest  16884.92400
# 1     18    male  33.770         1     no  southeast   1725.55230
# 2     28    male  33.000         3     no  southeast   4449.46200
# 3     33    male  22.705         0     no  northwest  21984.47061
# 4     32    male  28.880         0     no  northwest   3866.85520
# ..   ...     ...     ...       ...    ...        ...          ...
# 100   41  female  31.600         0     no  southwest   6186.12700
# 101   30    male  25.460         0     no  northeast   3645.08940
# 102   18  female  30.115         0     no  northeast  21344.84670
# 103   61  female  29.920         3    yes  southeast  30942.19180
# 104   34  female  27.500         1     no  southwest   5003.85300
#
# [100 rows x 7 columns]

# %%
# what is the var
df.var()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_1140\646168510.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# age         1.964592e+02
# bmi         3.583064e+01
# children    1.461736e+00
# charges     8.432259e+07
# dtype: float64

# %%
sns.boxplot(x='bmi',data=df);

# %%
df=df.query("bmi<40")

# %%
sns.boxplot(x='bmi',data=df)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1184.000000  1184.000000  1184.000000   1184.000000
# mean     38.554899    29.488361     1.087838  11331.549920
# std      14.020467     5.183084     1.203989   9208.118307
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    25.745000     0.000000   4525.093775
# 50%      38.000000    29.640000     1.000000   8790.531000
# 75%      51.000000    33.330000     2.000000  14152.412300
# max      64.000000    39.995000     5.000000  39983.425950

# %%
#  what is the  max bim 
df[df['bmi']==df['bmi'].max()]
# Out:
#      age     sex     bmi  children smoker     region     charges
# 978   45  female  39.995         3     no  northeast  9704.66805

# %%
df.columns=df.columns.str.capitalize()

# %%
df
# Out:
#       Age     Sex     Bmi  Children Smoker     Region      Charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1184 rows x 7 columns]

# %%
sns.set_theme(style="darkgrid")

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
sns.countplot(x='Sex',data=df)
plt.title('Count the sex');
plt.subplot(1,3,2)
sns.countplot(x='Smoker',data=df)
plt.title('Count the Smoker');
plt.subplot(1,3,3)
sns.countplot(x='Smoker',data=df,hue='Sex',palette="Set3");

# %%
sns.barplot(x='Sex',y='Children',data=df,hue='Smoker',color='r');

# %%
plt.figure(figsize=(15,8))

sns.countplot(x='Region',data=df,palette="Set3",hue='Sex');

# %%
plt.figure(figsize=(15,8))

sns.barplot(x='Sex',y='Charges',data=df,hue='Children',palette="Set3");

# %%
plt.figure(figsize=(15,8))

sns.countplot(x='Region',data=df,palette="Set2",hue='Smoker');

# %%
plt.figure(figsize=(30,8))
sns.barplot(x='Region',y='Bmi',data=df,palette="Set3");

# %%
plt.figure(figsize=(30,10))

sns.countplot(x='Age',data=df,palette="Set3",hue='Sex');

# %%
plt.subplot(1,3,1)
sns.barplot(x='Sex',y='Bmi',data=df,palette="Set3");
plt.subplot(1,3,2)
sns.barplot(x='Region',y='Charges',data=df);
plt.subplot(1,3,3)
sns.barplot(x='Smoker',y='Charges',data=df,palette="Set1");

# %%
plt.figure(figsize=(15,8))

sns.barplot(x='Sex',y='Charges',data=df,palette="Set1",hue='Children');
